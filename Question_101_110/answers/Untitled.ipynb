# %% [markdown]
# ## 通道、几何变换、裁剪

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
file_dir = r"../../Tutorial/images/imori.jpg"

# %%
# flag=-1时，8位深度，原通道
# flag=0，8位深度，1通道
# flag=1,   8位深度  ，3通道
# flag=2，原深度，1通道
# flag=3,  原深度，3通道

img = cv2.imread(file_dir, 0)
# 将图像转化为灰度图
# img = cv2Color(img, cv2.BGR2)

plt.imshow(img,cmap="gray")
plt.axis("off")
plt.show()
